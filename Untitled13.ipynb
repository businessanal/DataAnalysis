# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Aditya\\OneDrive\\Desktop\\loan data.csv")

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.isna().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.drop(columns=["person_emp_exp", "loan_percent_income", "cb_person_cred_hist_length", "previous_loan_defaults_on_file"], inplace = True)

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#       person_home_ownership  loan_amnt        loan_intent  loan_int_rate  \
# 0                      RENT      35000           PERSONAL          16.02
# ...

# %%
df.rename(columns={'person_age': 'Person Age'}, inplace = True)
df.rename(columns={'person_gender':'Person Gender'}, inplace = True)
df.rename(columns={'person_education':'Person Education'}, inplace = True)
df.rename(columns={'person_income':'Person Income'}, inplace = True)
df.rename(columns={'person_home_ownership':'Person Home Ownership'}, inplace = True)
df.rename(columns={'loan_amnt':'Loan Amount'}, inplace = True)
df.rename(columns={'loan_intent':'Loan Intent'}, inplace = True)
df.rename(columns={'loan_int_rate':'Loan Interest Rate'}, inplace = True)
df.rename(columns={'credit_score':'Credit Score'}, inplace = True)
df.rename(columns={'loan_status':'Loan Status'}, inplace = True)

# %%
df
# Out:
#        Person Age Person Gender Person Education  Person Income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#       Person Home Ownership  Loan Amount        Loan Intent  \
# 0                      RENT        35000           PERSONAL
# 1                       OWN         1000          EDUCATION
# ...

# %%
df['Loan Intent'].value_counts()
# Out:
# Loan Intent
# EDUCATION            9153
# MEDICAL              8548
# VENTURE              7819
# PERSONAL             7552
# DEBTCONSOLIDATION    7145
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
df['Loan Intent'] = df['Loan Intent'].replace({"DEBTCONSOLIDATION":"DEBT CONSOLIDATION", "HOMEIMPROVEMENT":"HOME IMPROVEMENT"})

# %%
df
# Out:
#        Person Age Person Gender Person Education  Person Income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#       Person Home Ownership  Loan Amount         Loan Intent  \
# 0                      RENT        35000            PERSONAL
# 1                       OWN         1000           EDUCATION
# ...

# %%
df['Person Gender'] = df['Person Gender'].str.title()

# %%
df['Person Home Ownership'] = df['Person Home Ownership'].str.title()

# %%
df['Loan Intent'] = df['Loan Intent'].str.title()

# %%
df
# Out:
#        Person Age Person Gender Person Education  Person Income  \
# 0              22        Female           Master          71948
# 1              21        Female      High School          12282
# 2              25        Female      High School          12438
# 3              23        Female         Bachelor          79753
# 4              24          Male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          Male        Associate          47971
# 44996          37        Female        Associate          65800
# 44997          33          Male        Associate          56942
# 44998          29          Male         Bachelor          33164
# 44999          24          Male      High School          51609
#
#       Person Home Ownership  Loan Amount         Loan Intent  \
# 0                      Rent        35000            Personal
# 1                       Own         1000           Education
# ...

# %%
df.head()
# Out:
#    Person Age Person Gender Person Education  Person Income  \
# 0          22        Female           Master          71948
# 1          21        Female      High School          12282
# 2          25        Female      High School          12438
# 3          23        Female         Bachelor          79753
# 4          24          Male           Master          66135
#
#   Person Home Ownership  Loan Amount Loan Intent  Loan Interest Rate  \
# 0                  Rent        35000    Personal               16.02
# 1                   Own         1000   Education               11.14
# 2              Mortgage         5500     Medical               12.87
# 3                  Rent        35000     Medical               15.23
# 4                  Rent        35000     Medical               14.27
#
#    Credit Score  Loan Status
# 0           561            1
# 1           504            0
# 2           635            1
# 3           675            1
# 4           586            1

# %%
df.tail()
# Out:
#        Person Age Person Gender Person Education  Person Income  \
# 44995          27          Male        Associate          47971
# 44996          37        Female        Associate          65800
# 44997          33          Male        Associate          56942
# 44998          29          Male         Bachelor          33164
# 44999          24          Male      High School          51609
#
#       Person Home Ownership  Loan Amount         Loan Intent  \
# 44995                  Rent        15000             Medical
# 44996                  Rent         9000    Home Improvement
# 44997                  Rent         2771  Debt Consolidation
# 44998                  Rent        12000           Education
# 44999                  Rent         6665  Debt Consolidation
#
#        Loan Interest Rate  Credit Score  Loan Status
# 44995               15.66           645            1
# 44996               14.07           621            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Person Age             45000 non-null  int64
#  1   Person Gender          45000 non-null  object
#  2   Person Education       45000 non-null  object
#  3   Person Income          45000 non-null  int64
#  4   Person Home Ownership  45000 non-null  object
#  5   Loan Amount            45000 non-null  int64
#  6   Loan Intent            45000 non-null  object
#  7   Loan Interest Rate     45000 non-null  float64
#  8   Credit Score           45000 non-null  int64
#  9   Loan Status            45000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 3.4+ MB

# %%
df.dtypes
# Out:
# Person Age                 int64
# Person Gender             object
# Person Education          object
# Person Income              int64
# Person Home Ownership     object
# Loan Amount                int64
# Loan Intent               object
# Loan Interest Rate       float64
# Credit Score               int64
# Loan Status                int64
# dtype: object

# %%
df.describe()
# Out:
#          Person Age  Person Income   Loan Amount  Loan Interest Rate  \
# count  45000.000000   4.500000e+04  45000.000000        45000.000000
# mean      27.764178   8.031905e+04   9583.157556           11.006606
# std        6.045108   8.042250e+04   6314.886691            2.978808
# min       20.000000   8.000000e+03    500.000000            5.420000
# 25%       24.000000   4.720400e+04   5000.000000            8.590000
# 50%       26.000000   6.704800e+04   8000.000000           11.010000
# 75%       30.000000   9.578925e+04  12237.250000           12.990000
# max      144.000000   7.200766e+06  35000.000000           20.000000
#
#        Credit Score   Loan Status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
mean_score = df['Credit Score'].mean().round(0)
mean_income = df['Person Income'].mean().round(0)
mean_age = df['Person Age'].mean().round(0)

# %%
print(mean_score)
print(mean_income)
print(mean_age)
# Out:
# 633.0
# 80319.0
# 28.0

# %%
df['Person Gender'].value_counts()
# Out:
# Person Gender
# Male      24841
# Female    20159
# Name: count, dtype: int64

# %%
df['Person Education'].value_counts()
# Out:
# Person Education
# Bachelor       13399
# Associate      12028
# High School    11972
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
df['Person Home Ownership'].value_counts()
# Out:
# Person Home Ownership
# Rent        23443
# Mortgage    18489
# Own          2951
# Other         117
# Name: count, dtype: int64

# %%
df['Loan Intent'].value_counts()
# Out:
# Loan Intent
# Education             9153
# Medical               8548
# Venture               7819
# Personal              7552
# Debt Consolidation    7145
# Home Improvement      4783
# Name: count, dtype: int64

# %%
df['Loan Status'].value_counts()
# Out:
# Loan Status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %%
male_count = 24841
female_count = 20159

# %%
total_count = male_count + female_count

# %%
total_count
# Out:
# 45000

# %%
percentage_male_count = (male_count/total_count)*100
percentage_female_count = (female_count/total_count)*100

percentage_male_count_rounded = round(percentage_male_count,0)
percentage_female_count_rounded = round(percentage_female_count,0)

# %%
print(percentage_male_count_rounded)
print(percentage_female_count_rounded)
# Out:
# 55.0
# 45.0

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x='Person Education', y = 'Person Income', data = df)
plt.title("Person Education as per Income")
plt.xlabel("Education Qualification")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
sns.barplot(x='Person Gender', y = 'Person Income', data = df)
plt.title("Gender as per Income")
plt.xlabel("Gender")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
loan_intent = ["Education", "Medical", "Venture", "Personal", "Debt Consolidation", "Home Improvement"]
value = [9153,8548,7819,7552,7145,4783]

# %%
plt.bar(loan_intent,value)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Education'),
#   Text(1, 0, 'Medical'),
#   Text(2, 0, 'Venture'),
#   Text(3, 0, 'Personal'),
#   Text(4, 0, 'Debt Consolidation'),
#   Text(5, 0, 'Home Improvement')])

# %%
Person_home_ownership = ["Rent", "Mortgage", "Own", "Other"]
value_2 = [23443,18489,2951,117]

# %%
sns.

# %%
sns.histplot(df['Person Age'], bins = 15, edgecolor='black')
# Out:
# <Axes: xlabel='Person Age', ylabel='Count'>
